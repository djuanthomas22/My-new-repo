# %% [markdown]
# <a href="https://colab.research.google.com/github/djuanthomas22/My-new-repo/blob/main/Password.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
password = input("Enter your password: ")
# Out:
# Enter your password: incognito

# %%
condition = "#" in password

# %%
if condition:
    print("Password is valid")
else:
    print("Password needs a #")
# Out:
# Password needs a #
