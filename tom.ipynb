# %%
print('say cheese')
# Out:
# say cheese

# %%
name = "DJuan"
age = 27
print(f"My name is {name} and I’m {age} years old.")
# Out:
# My name is DJuan and I’m 27 years old.

# %%
a, b = 5, 3
print(f"{a} + {b} = {a + b}")
# Out:
# 5 + 3 = 8

# %%
user = "DJuan"
level = 12
message = f"Welcome, {user}! {f'You’re level {level}.'}"
print(message)
# Out:
# Welcome, DJuan! You’re level 12.
